# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("training_jobs.csv")

# %%
plt.figure(figsize=(15, 10))
df[['model_size', 'dataset_size', 'batch_size', 'epochs']].hist(bins=20, figsize=(15, 10))  # 可以调整 bins 数量
plt.suptitle('Feature Distribution', fontsize=16)
plt.grid(False)  # 禁用网格
plt.gca().set_facecolor('white')  # 设置背景为白色
plt.tight_layout()
plt.show()
